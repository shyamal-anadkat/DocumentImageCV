# %% [markdown]
# google image scraper utility tool for aipi540 cv project
#
# Usage: https://google-images-download.readthedocs.io/en/latest/arguments.html

# %%
# !git clone https://github.com/Joeclinton1/google-images-download.git
# Out:
# Cloning into 'google-images-download'...

# %%
cd google-images-download/
# Out:
# C:\Users\Chris\Desktop\MIDS\Spring_2022\AIPI_DeepLearning\AIPI540_ComputerVision\data\google-images-download

# %%
# !pip install -r requirements.txt
# !python setup.py install
# Out:
# ...
# zip_safe flag not set; analyzing archive contents...
# running install
# running bdist_egg
# running egg_info
# creating google_images_download.egg-info
# writing google_images_download.egg-info\PKG-INFO
# writing dependency_links to google_images_download.egg-info\dependency_links.txt
# writing entry points to google_images_download.egg-info\entry_points.txt
# writing requirements to google_images_download.egg-info\requires.txt
# writing top-level names to google_images_download.egg-info\top_level.txt
# writing manifest file 'google_images_download.egg-info\SOURCES.txt'
# reading manifest file 'google_images_download.egg-info\SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'google_images_download.egg-info\SOURCES.txt'
# installing library code to build\bdist.win32\egg
# running install_lib
# running build_py
# creating build
# creating build\lib
# creating build\lib\google_images_download
# ...

# %%
# !googleimagesdownload -u "https://www.google.com/search?q=russian%20text&tbm=isch&hl=en&tbs=rimg:CUjPJwSo9B99YaZKCOz9Z4FusgIGOgQIARAA&sa=X&ved=0CAIQrnZqFwoTCOjD7ZLP1PUCFQAAAAAdAAAAABAH&biw=1703&bih=1300" -l 100 -f "jpg" -ct "black-and-white" -la "Russian" -s ">640*480"
# Out:
# Item no.: 1 --> Item name = 2022-01-28 09_07_08
# Evaluating...
# Starting Download...
# Completed Image ====> 1.russian-text.png
# Completed Image ====> 2.0fe9df5fb32bc3f153176a740f61e27e.jpg
# Completed Image ====> 3.vf1de.jpg
# Completed Image ====> 4.rst.jpg
# Completed Image ====> 5.russian-regular-sample.png
# Completed Image ====> 6.slovo_o_polku_igoreve_text.png
# Completed Image ====> 7.excel_to_csv_russian_text_1.png
# Completed Image ====> 8.00russian_alphabet_3.jpg
# Completed Image ====> 9.russian-natural-language-processing_4.png
# Completed Image ====> 10.russian-alphabet-cyrillic-uppercase-lowercase-260nw-1208950438.jpg
# Completed Image ====> 11.cyril.gif
# Completed Image ====> 12.droppedimage_2.jpg
# Completed Image ====> 13.68747470733a2f2f662e636c6f75642e6769746875622e636f6d2f6173736574732f313933353232392f313333363731332f35303030346632612d333563622d313165332d383761632d6466643439333834623664372e706e67.png
# ...

# %%
# !googleimagesdownload -u "https://www.google.com/search?q=russian%20text&tbm=isch&hl=en&tbs=rimg:CVrOSnrbVJCkYdTlzuT2pgdBsgIGOgQIARAA&sa=X&ved=0CAIQrnZqFwoTCLjq8ZzP1PUCFQAAAAAdAAAAABAL&biw=1703&bih=1300" -l 100 -f "jpg" -ct "black-and-white" -la "Russian" -s ">640*480"
# Out:
# Item no.: 1 --> Item name = 2022-01-28 09_08_14
# Evaluating...
# Starting Download...
# Completed Image ====> 1.russian-text.png
# Completed Image ====> 2.vf1de.jpg
# Completed Image ====> 3.o-umlaut-as-yo-in-russian-text.jpg
# Completed Image ====> 4.povest_vremennykh_let_text.png
# Completed Image ====> 5.0fe9df5fb32bc3f153176a740f61e27e.jpg
# Completed Image ====> 6.russian-natural-language-processing_4.png
# Completed Image ====> 7.rst.jpg
# Completed Image ====> 8.maxresdefault.jpg
# Completed Image ====> 9.russian-regular-sample.png
# Completed Image ====> 10.68747470733a2f2f662e636c6f75642e6769746875622e636f6d2f6173736574732f313933353232392f313333363731322f34666534646332322d333563622d313165332d383731362d3161636264393333663038302e706e67.png
# Completed Image ====> 11.cyrillicfonts023.jpg
# Completed Image ====> 12.latest.jpg
# Completed Image ====> 13.excel_to_csv_russian_text_1.png
# Completed Image ====> 14.xviii_century_russian_font.png
# Completed Image ====> 15.r-1.jpg
# ...

# %%
https://www.google.com/search?q=russian%20text&tbm=isch&hl=en&tbs=rimg:CVrOSnrbVJCkYdTlzuT2pgdBsgIGOgQIARAA&sa=X&ved=0CAIQrnZqFwoTCLjq8ZzP1PUCFQAAAAAdAAAAABAL&biw=1703&bih=1300
# Out:
#   adding: downloads/russian documents/ (stored 0%)
#   adding: downloads/russian documents/94.eof4sfywoaag-89.jpg (deflated 5%)
#   adding: downloads/russian documents/50.image.jpg (deflated 1%)
#   adding: downloads/russian documents/52.0kynourw16x71.jpg (deflated 0%)
#   adding: downloads/russian documents/26.figure4_covidvaccinationform.jpg (deflated 5%)
#   adding: downloads/russian documents/61.sampledoc1.jpg (deflated 1%)
#   adding: downloads/russian documents/49.transcribe-an-old-russian-document-and-translate-it-4655.png.jpg (deflated 0%)
#   adding: downloads/russian documents/10.russian_draft_turovsky_1272pg3.jpg (deflated 0%)
#   adding: downloads/russian documents/92.pl_1_439_156_0006.jpg (deflated 2%)
#   adding: downloads/russian documents/65.eof4sfxx0ae_wo1.jpg (deflated 6%)
#   adding: downloads/russian documents/71.fai-43167.jpg (deflated 2%)
# ...

# %%
import os
os.getcwd()

os.chdir('data')

os.getcwd()
# Out:
# 'C:\\Users\\Chris\\Desktop\\MIDS\\Spring_2022\\AIPI_DeepLearning\\AIPI540_ComputerVision\\data'

# %%
from difPy import dif

print('Deleting duplicate russian images...')
dif("raw/russian", delete=True, similarity="high")

print('Deleting duplicate telugu images...')
dif("raw/telugu", delete=True, similarity="high")

print('Deleting duplicate english images...')
dif("raw/english", delete=True, similarity="high")
# Out:
# Deleting duplicate russian images...
# Found 97 images with one or more duplicate/similar images in 35.353 seconds.
# Are you sure you want to delete all lower resolution duplicate images?
# This cannot be undone. (y/n) y
# Deletion in progress...
# Deleted file: raw/russian/74.russian-alphabet-468.jpg
#
# ***
# Deleted 1 duplicates/similar images.
#
# Deletion in progress...
# Deleted file: raw/russian/57.rychkov-f5-rus-sample.jpg
#
# ***
# Deleted 1 duplicates/similar images.
#
# Deletion in progress...
# Deleted file: raw/russian/100.kalm.jpg
#
# ***
# Deleted 1 duplicates/similar images.
#
# Deletion in progress...
# Deleted file: raw/russian/19.screenshot2.png
#
# ***
# Deleted 1 duplicates/similar images.
#
# Deletion in progress...
# Deleted file: raw/russian/92.b19d95a08d5a73e3816f8a86c155fa16--english-verbs-russia-language.jpg
#
# ***
# Deleted 1 duplicates/similar images.
#
# Deletion in progress...
# Deleted file: raw/russian/34.1483039.jpg
#
# ***
# ...
